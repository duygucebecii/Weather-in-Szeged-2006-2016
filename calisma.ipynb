# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('weatherHistory.csv')

# %%
df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
df.tail()
# Out:
#                       Formatted Date        Summary Precip Type  \
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 96448        26.016667                 26.016667      0.43            10.9963
# 96449        24.583333                 24.583333      0.48            10.0947
# 96450        22.038889                 22.038889      0.56             8.9838
# 96451        21.522222                 21.522222      0.60            10.5294
# 96452        20.438889                 20.438889      0.61             5.8765
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# ...

# %%
df.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB

# %%
df.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       96453.000000            96453.000000     96453.000000     96453.0
# mean           10.810640              187.509232        10.347325         0.0
# std             6.913571              107.383428         4.192123         0.0
# min             0.000000                0.000000         0.000000         0.0
# ...

# %%
df.isnull().sum()
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Loud Cover                    0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %%
df["Precip Type"].unique()
# Out:
# array(['rain', 'snow', nan], dtype=object)

# %%
df["Precip Type"].value_counts()
# Out:
# Precip Type
# rain    85224
# snow    10712
# Name: count, dtype: int64

# %%
df= df.dropna().reset_index(drop=True)

# %%
df.isnull().sum()
# Out:
# Formatted Date              0
# Summary                     0
# Precip Type                 0
# Temperature (C)             0
# Apparent Temperature (C)    0
# Humidity                    0
# Wind Speed (km/h)           0
# Wind Bearing (degrees)      0
# Visibility (km)             0
# Loud Cover                  0
# Pressure (millibars)        0
# Daily Summary               0
# dtype: int64

# %%
df["Precip Type"].unique()
# Out:
# array(['rain', 'snow'], dtype=object)

# %%
df["Formatted Date"].unique()
# Out:
# array(['2006-04-01 00:00:00.000 +0200', '2006-04-01 01:00:00.000 +0200',
#        '2006-04-01 02:00:00.000 +0200', ...,
#        '2016-09-09 21:00:00.000 +0200', '2016-09-09 22:00:00.000 +0200',
#        '2016-09-09 23:00:00.000 +0200'], dtype=object)

# %%
df["Formatted Date"] = pd.to_datetime(df["Formatted Date"], utc=True)

# %%
df["Day"] = df["Formatted Date"].dt.day
df["Month"] = df["Formatted Date"].dt.month
df["Year"] = df["Formatted Date"].dt.year
df["Hour"] = df["Formatted Date"].dt.hour

# %%
df.head()
# Out:
#              Formatted Date        Summary Precip Type  Temperature (C)  \
# 0 2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 1 2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2 2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 3 2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 4 2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df["Precip Type"] = le.fit_transform(df["Precip Type"])

# %%
df.head()
# Out:
#              Formatted Date        Summary  Precip Type  Temperature (C)  \
# 0 2006-03-31 22:00:00+00:00  Partly Cloudy            0         9.472222
# 1 2006-03-31 23:00:00+00:00  Partly Cloudy            0         9.355556
# 2 2006-04-01 00:00:00+00:00  Mostly Cloudy            0         9.377778
# 3 2006-04-01 01:00:00+00:00  Partly Cloudy            0         8.288889
# 4 2006-04-01 02:00:00+00:00  Mostly Cloudy            0         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
df["Summary"].unique()
# Out:
# array(['Partly Cloudy', 'Mostly Cloudy', 'Overcast', 'Foggy',
#        'Breezy and Mostly Cloudy', 'Clear', 'Breezy and Partly Cloudy',
#        'Breezy and Overcast', 'Humid and Mostly Cloudy',
#        'Humid and Partly Cloudy', 'Windy and Foggy', 'Windy and Overcast',
#        'Breezy and Foggy', 'Windy and Partly Cloudy', 'Breezy',
#        'Dry and Partly Cloudy', 'Windy and Mostly Cloudy',
#        'Dangerously Windy and Partly Cloudy', 'Dry', 'Windy',
#        'Humid and Overcast', 'Light Rain', 'Drizzle', 'Windy and Dry',
#        'Dry and Mostly Cloudy', 'Breezy and Dry', 'Rain'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95936 entries, 0 to 95935
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            95936 non-null  datetime64[ns, UTC]
#  1   Summary                   95936 non-null  object
#  2   Precip Type               95936 non-null  int64
#  3   Temperature (C)           95936 non-null  float64
#  4   Apparent Temperature (C)  95936 non-null  float64
#  5   Humidity                  95936 non-null  float64
#  6   Wind Speed (km/h)         95936 non-null  float64
#  7   Wind Bearing (degrees)    95936 non-null  float64
#  8   Visibility (km)           95936 non-null  float64
#  9   Loud Cover                95936 non-null  float64
#  10  Pressure (millibars)      95936 non-null  float64
#  11  Daily Summary             95936 non-null  object
#  12  Day                       95936 non-null  int32
# ...

# %%
int_deg=["Day","Month","Year","Hour","Precip Type"]

# %%
df_copy = df.copy()

# %%
df_copy[int_deg] = df_copy[int_deg].astype(float)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95936 entries, 0 to 95935
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            95936 non-null  datetime64[ns, UTC]
#  1   Summary                   95936 non-null  object
#  2   Precip Type               95936 non-null  float64
#  3   Temperature (C)           95936 non-null  float64
#  4   Apparent Temperature (C)  95936 non-null  float64
#  5   Humidity                  95936 non-null  float64
#  6   Wind Speed (km/h)         95936 non-null  float64
#  7   Wind Bearing (degrees)    95936 non-null  float64
#  8   Visibility (km)           95936 non-null  float64
#  9   Loud Cover                95936 non-null  float64
#  10  Pressure (millibars)      95936 non-null  float64
#  11  Daily Summary             95936 non-null  object
#  12  Day                       95936 non-null  float64
# ...

# %%
df_copy = df_copy.drop(columns=["Formatted Date"])

# %%
numeric_features = df_copy.select_dtypes(include=['float64'])

# %%
numeric_features.corr()
# Out:
#                           Precip Type  Temperature (C)  \
# Precip Type                  1.000000        -0.563503
# Temperature (C)             -0.563503         1.000000
# Apparent Temperature (C)    -0.566058         0.992637
# Humidity                     0.232622        -0.632148
# Wind Speed (km/h)           -0.067771         0.008304
# Wind Bearing (degrees)      -0.042142         0.029937
# Visibility (km)             -0.316483         0.393719
# Loud Cover                        NaN              NaN
# Pressure (millibars)         0.009271        -0.005253
# Day                          0.010835        -0.000501
# Month                       -0.145782         0.150479
# Year                        -0.044063         0.019392
# Hour                        -0.051235         0.099310
#
#                           Apparent Temperature (C)  Humidity  \
# Precip Type                              -0.566058  0.232622
# Temperature (C)                           0.992637 -0.632148
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(numeric_features.corr(),annot=True)
plt.show()

# %%
plt.subplot(1,2,1)
sns.lineplot(x="Apparent Temperature (C)",y="Visibility (km)",data=df_copy)
plt.xlabel("Apparent Temperature (C)")
plt.ylabel("Visibility (km)")
plt.subplot(1,2,2)
sns.lineplot(x=df_copy["Temperature (C)"],y=df_copy["Visibility (km)"])
plt.xlabel("Temperature (C)")
plt.ylabel("Visibility (km)")
plt.show()

# %%
X = df_copy[["Temperature (C)","Apparent Temperature (C)","Humidity","Wind Speed (km/h)","Wind Bearing (degrees)","Visibility (km)","Loud Cover","Pressure (millibars)","Day","Month","Year","Hour"]]
y= df_copy["Precip Type"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.2,random_state=15)

# %%
X.head()
# Out:
#    Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0         9.472222                  7.388889      0.89            14.1197
# 1         9.355556                  7.227778      0.86            14.2646
# 2         9.377778                  9.377778      0.89             3.9284
# 3         8.288889                  5.944444      0.83            14.1036
# 4         8.755556                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
# 2                   204.0          14.9569         0.0               1015.94
# 3                   269.0          15.8263         0.0               1016.41
# 4                   259.0          15.8263         0.0               1016.51
#
#     Day  Month    Year  Hour
# ...

# %%
y.value_counts()
# Out:
# Precip Type
# 0.0    85224
# 1.0    10712
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[ 1.48241924,  1.42443167, -0.69141254, ...,  0.13771674,
#         -0.62839676,  0.64938715],
#        [ 0.11969451,  0.20749296,  0.33231049, ..., -0.73105563,
#          0.32288095, -0.36112467],
#        [ 1.36503314,  1.31960369, -1.66394943, ...,  0.42730754,
#         -1.2625819 ,  0.93810481],
#        ...,
#        [ 0.84318802,  0.85358622, -1.40801867, ...,  0.71689833,
#         -1.57967447, -0.21676584],
#        [ 0.72696416,  0.74979614, -1.30564637, ..., -0.73105563,
#          0.32288095,  0.79374598],
#        [ 0.8606216 ,  0.86915473, -1.71513558, ...,  1.00648912,
#         -1.57967447,  0.50502831]])

# %%
X_test
# Out:
# array([[ 0.03426997,  0.13120725,  0.6394274 , ..., -0.44146484,
#         -1.2625819 , -1.51599532],
#        [-1.03847624, -0.82677521,  0.94654431, ...,  1.00648912,
#         -0.31130419, -0.93856   ],
#        [-0.20980013, -0.28602888,  0.69061355, ...,  1.29607991,
#         -0.31130419, -0.64984233],
#        ...,
#        [-0.32602399, -0.52474607,  0.99773046, ..., -0.44146484,
#         -0.31130419, -0.07240701],
#        [ 0.83505235,  0.84632092,  0.07637973, ...,  0.13771674,
#          1.59125123,  1.3711813 ],
#        [ 0.19988897,  0.27910812, -0.33310948, ...,  1.00648912,
#          0.32288095, -0.36112467]])

# %%
from sklearn.linear_model import LinearRegression

# %%
regression = LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regression.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error,r2_score

# %%
mse = mean_squared_error(y_test,y_pred)
mae= mean_absolute_error(y_test,y_pred)
score = r2_score(y_test,y_pred)
print("mse: ",mse)
print("mae: ",mae)
print("r2 score: ",score)
# Out:
# mse:  0.06140187950826937
# mae:  0.1851376456732255
# r2 score:  0.38460949573555303
